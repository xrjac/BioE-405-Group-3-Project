# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv ("diabetes.tab.txt",sep='\t')
df.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
#Print the full summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AGE     442 non-null    int64
#  1   SEX     442 non-null    int64
#  2   BMI     442 non-null    float64
#  3   BP      442 non-null    float64
#  4   S1      442 non-null    int64
#  5   S2      442 non-null    float64
#  6   S3      442 non-null    float64
#  7   S4      442 non-null    float64
#  8   S5      442 non-null    float64
#  9   S6      442 non-null    int64
#  10  Y       442 non-null    int64
# dtypes: float64(6), int64(5)
# memory usage: 38.1 KB

# %% [markdown]
# TASK 1: Compute mean values and variance for all values

# %%
#AGE
mean = df['AGE'].mean()
var = df['AGE'].var()
std = df['AGE'].std()
print(f"Mean = {mean}\nVariance = {var}\nStandard Deviation = {std}")
# Out:
# Mean = 48.51809954751131
# Variance = 171.84661043904728
# Standard Deviation = 13.109027822041087

# %%
#SEX
mean = df['SEX'].mean()
var = df['SEX'].var()
std = df['SEX'].std()
print(f"Mean = {mean}\nVariance = {var}\nStandard Deviation = {std}")
# Out:
# Mean = 1.4683257918552035
# Variance = 0.24956136300674067
# Standard Deviation = 0.49956117043535386

# %%
#BP
mean = df['BP'].mean()
var = df['BP'].var()
std = df['BP'].std()
print(f"Mean = {mean}\nVariance = {var}\nStandard Deviation = {std}")
# Out:
# Mean = 94.64701357466062
# Variance = 191.30440103836415
# Standard Deviation = 13.831283419783

# %%
#S1
mean = df['S1'].mean()
var = df['S1'].var()
std = df['S1'].std()
print(f"Mean = {mean}\nVariance = {var}\nStandard Deviation = {std}")
# Out:
# Mean = 189.14027149321268
# Variance = 1197.717240742452
# Standard Deviation = 34.60805167504308

# %%
#S2
mean = df['S2'].mean()
var = df['S2'].var()
std = df['S2'].std()
print(f"Mean = {mean}\nVariance = {var}\nStandard Deviation = {std}")
# Out:
# Mean = 115.43914027149322
# Variance = 924.9554940437704
# Standard Deviation = 30.413080969276532

# %%
#S3
mean = df['S3'].mean()
var = df['S3'].var()
std = df['S3'].std()
print(f"Mean = {mean}\nVariance = {var}\nStandard Deviation = {std}")
# Out:
# Mean = 49.78846153846154
# Variance = 167.29358538287124
# Standard Deviation = 12.934202154863332

# %%
#S4
mean = df['S4'].mean()
var = df['S4'].var()
std = df['S4'].std()
print(f"Mean = {mean}\nVariance = {var}\nStandard Deviation = {std}")
# Out:
# Mean = 4.070248868778281
# Variance = 1.6652609356563135
# Standard Deviation = 1.2904498966082774

# %%
#S5
mean = df['S5'].mean()
var = df['S5'].var()
std = df['S5'].std()
print(f"Mean = {mean}\nVariance = {var}\nStandard Deviation = {std}")
# Out:
# Mean = 4.641410859728507
# Variance = 0.2728918982944974
# Standard Deviation = 0.5223905610694908

# %%
#S6
mean = df['S6'].mean()
var = df['S6'].var()
std = df['S6'].std()
print(f"Mean = {mean}\nVariance = {var}\nStandard Deviation = {std}")
# Out:
# Mean = 91.26018099547511
# Variance = 132.16571243882152
# Standard Deviation = 11.496334739334165

# %%
#Y
mean = df['Y'].mean()
var = df['Y'].var()
std = df['Y'].std()
print(f"Mean = {mean}\nVariance = {var}\nStandard Deviation = {std}")
# Out:
# Mean = 152.13348416289594
# Variance = 5943.331347923785
# Standard Deviation = 77.09300453299109

# %% [markdown]
# TASK 2: Plot boxplots for BMI, BP and Y depending on gender

# %%
plt.figure(figsize=(10,2))
plt.boxplot(df['BMI'],vert=False, showmeans=True)
plt.grid(color='gray',linestyle='dotted')
plt.show()

# %%
plt.figure(figsize=(10,2))
plt.boxplot(df['BP'],vert=False, showmeans=True)
plt.grid(color='gray',linestyle='dotted')
plt.show()

# %%
plt.figure(figsize=(10,2))
plt.boxplot(df['Y'],vert=False, showmeans=True)
plt.grid(color='gray',linestyle='dotted')
plt.show()

# %% [markdown]
# TASK 3: What is the distribution of AGE, SEX, BMI and Y variables?

# %%
df['AGE'].hist(bins=15)
plt.suptitle('AGE distribution of diabetes patient')
plt.xlabel('AGE')
plt.ylabel('Count')
plt.show()

# %%
df['SEX'].hist(bins=15)
plt.suptitle('SEX distribution of diabetes patient')
plt.xlabel('SEX')
plt.ylabel('Count')
plt.show()

# %%
df['BMI'].hist(bins=15)
plt.suptitle('BMI distribution of diabetes patient')
plt.xlabel('BMI')
plt.ylabel('Count')
plt.show()

# %%
df['Y'].hist(bins=15)
plt.suptitle('Y distribution of diabetes patient')
plt.xlabel('Y')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# TASK 4: Test the correlation between different variable and disease progression (Y)

# %%
#AGE VS Y
plt.scatter(df['AGE'], df['Y'])
plt.title('AGE vs. Y')
plt.xlabel('AGE')
plt.ylabel('Y')
plt.show()

# %%
#BMI VS Y
plt.scatter(df['BMI'], df['Y'])
plt.title('BMI vs. Y')
plt.xlabel('BMI')
plt.ylabel('Y')
plt.show()
